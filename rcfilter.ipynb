# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
from scipy.fft import fft, fftfreq

# %%
num_taps = 101
beta = 0.3
Ts = 16
t = np.arange(-51,52)
rc_filt = np.sinc(t/Ts) * np.cos(np.pi*beta*t/Ts) / (1 - (2*beta*t/Ts)**2)

#w, h = signal.freqz(rc_filt)
plt.plot(abs(fft(rc_filt)))
#plt.plot(t, rc_filt, '.')
#plt.plot(w,abs(h))
plt.show()
